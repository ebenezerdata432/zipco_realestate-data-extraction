# %%
import requests
import pandas as pd
import psycopg2
import json

# %%
url = "https://api.rentcast.io/v1/properties/random?limit=900"

headers = {
    "accept": "application/json",
    "X-Api-Key": "fab36e69bae842689d2c4599abdbb48b"
}

response = requests.get(url, headers=headers)

print(response.json())
# Out:
# [{'id': '7035-Broadway,-Apt-C9,-Jackson-Heights,-NY-11372', 'formattedAddress': '7035 Broadway, Apt C9, Jackson Heights, NY 11372', 'addressLine1': '7035 Broadway', 'addressLine2': 'Apt C9', 'city': 'Jackson Heights', 'state': 'NY', 'zipCode': '11372', 'county': 'Queens', 'latitude': 40.748368, 'longitude': -73.894704, 'propertyType': 'Apartment', 'squareFootage': 110000, 'lotSize': 23959, 'yearBuilt': 1927, 'assessorID': '01282-0175C9', 'legalDescription': 'LOT:175 BLK:1282', 'zoning': 'R6', 'features': {'floorCount': 6, 'unitCount': 135}, 'taxAssessments': {'2019': {'year': 2019, 'value': 4246200, 'land': 862650, 'improvements': 3383550}, '2021': {'year': 2021}, '2023': {'year': 2023}, '2024': {'year': 2024}}, 'propertyTaxes': {'2019': {'year': 2019, 'total': 316873}}, 'owner': {'names': ['Peiwen Liang'], 'type': 'Individual', 'mailingAddress': {'id': '7035-BROADWAY,-APT-C9,-Flushing,-NY-11372', 'formattedAddress': '7035 BROADWAY, APT C9, Flushing, NY 11372', 'addressLine1': '7035 BROADWAY', 'addressLine2': 'APT C9', 'city': 'Flushing', 'state': 'NY', 'zipCode': '11372'}}, 'ownerOccupied': True}, {'id': '2726-N-79th-St,-Omaha,-NE-68134', 'formattedAddress': '2726 N 79th St, Omaha, NE 68134', 'addressLine1': '2726 N 79th St', 'addressLine2': None, 'city': 'Omaha', 'state': 'NE', 'zipCode': '68134', 'county': 'Douglas', 'latitude': 41.283931, 'longitude': -96.036133, 'propertyType': 'Single Family', 'bedrooms': 2, 'bathrooms': 1, 'squareFootage': 896, 'lotSize': 16906, 'yearBuilt': 1952, 'assessorID': '0633290002', 'legalDescription': 'BENSON GARDENS LOT 155 BLOCK 0 N 157.5 FT 107 X 157.5 FT', 'subdivision': 'BENSON GARDENS', 'features': {'architectureType': 'Ranch', 'cooling': True, 'coolingType': 'Central', 'exteriorType': 'Other', 'floorCount': 1, 'foundationType': 'Block', 'garage': True, 'garageType': 'Attached', 'heating': True, 'heatingType': 'Central', 'roofType': 'Composition Shingle', 'roomCount': 4, 'unitCount': 1}, 'taxAssessments': {'2023': {'year': 2023, 'value': 149100, 'land': 21800, 'improvements': 127300}, '2024': {'year': 2024, 'value': 167900, 'land': 21800, 'improvements': 146100}}, 'propertyTaxes': {'2023': {'year': 2023, 'total': 3146}}, 'owner': {'names': ['Bert W Thompson'], 'type': 'Individual', 'mailingAddress': {'id': '2726-N-79th-St,-Omaha,-NE-68134', 'formattedAddress': '2726 N 79th St, Omaha, NE 68134', 'addressLine1': '2726 N 79th St', 'addressLine2': None, 'city': 'Omaha', 'state': 'NE', 'zipCode': '68134'}}, 'ownerOccupied': True}, {'id': '635-W-Redondo-Pl,-Green-Valley,-AZ-85614', 'formattedAddress': '635 W Redondo Pl, Green Valley, AZ 85614', 'addressLine1': '635 W Redondo Pl', 'addressLine2': None, 'city': 'Green Valley', 'state': 'AZ', 'zipCode': '85614', 'county': 'Pima', 'latitude': 31.855366, 'longitude': -111.000775, 'propertyType': 'Condo', 'bedrooms': 2, 'bathrooms': 2, 'squareFootage': 1559, 'lotSize': 3650, 'yearBuilt': 1978, 'assessorID': '304-26-7190', 'legalDescription': 'CONTINENTAL VISTAS RESUB TOWNHOUSES LOT 230', 'subdivision': 'CONTINENTAL VISTAS RESUB TOWNHOUSES', 'lastSaleDate': '2021-05-10T00:00:00.000Z', 'lastSalePrice': 209900, 'hoa': {'fee': 31}, 'features': {'architectureType': 'Condo / Apartment', 'cooling': True, 'coolingType': 'Refrigeration', 'exteriorType': 'Wood', 'floorCount': 1, 'garage': True, 'garageSpaces': 1, 'garageType': 'Garage', 'heating': True, 'heatingType': 'Forced Air', 'roofType': 'Roll Composition', 'roomCount': 1, 'unitCount': 1}, 'taxAssessments': {'2023': {'year': 2023, 'value': 18491}, '2025': {'year': 2025, 'value': 22338}}, 'propertyTaxes': {'2022': {'year': 2022, 'total': 1229}, '2024': {'year': 2024, 'total': 1390}}, 'history': {'2021-05-10': {'event': 'Sale', 'date': '2021-05-10T00:00:00.000Z', 'price': 209900}}, 'owner': {'names': ['Rex E Derr', 'Marianne Derr'], 'type': 'Individual', 'mailingAddress': {'id': '112-Skyline-Dr-NW,-Great-Falls,-MT-59404', 'formattedAddress': '112 Skyline Dr NW, Great Falls, MT 59404', 'addressLine1': '112 ...

# %%
data = response.json()

file_name = 'real_estate.json'

with open(file_name, 'w') as file:
    json.dump(data,file, indent=4)

# %%
real_estate_df = pd.read_json('real_estate.json')
real_estate_df.head()
# Out:
#                                                  id  \
# 0  7035-Broadway,-Apt-C9,-Jackson-Heights,-NY-11372
# 1                   2726-N-79th-St,-Omaha,-NE-68134
# 2          635-W-Redondo-Pl,-Green-Valley,-AZ-85614
# 3             3300-44th-Street-Ct,-Moline,-IL-61265
# 4                     8-Ritten-Ct,-Durham,-NC-27712
#
#                                    formattedAddress         addressLine1  \
# 0  7035 Broadway, Apt C9, Jackson Heights, NY 11372        7035 Broadway
# 1                   2726 N 79th St, Omaha, NE 68134       2726 N 79th St
# 2          635 W Redondo Pl, Green Valley, AZ 85614     635 W Redondo Pl
# 3             3300 44th Street Ct, Moline, IL 61265  3300 44th Street Ct
# 4                     8 Ritten Ct, Durham, NC 27712          8 Ritten Ct
#
#   addressLine2             city state  zipCode       county   latitude  \
# 0       Apt C9  Jackson Heights    NY    11372       Queens  40.748368
# 1         None            Omaha    NE    68134      Douglas  41.283931
# 2         None     Green Valley    AZ    85614         Pima  31.855366
# 3         None           Moline    IL    61265  Rock Island  41.479891
# 4         None           Durham    NC    27712       Durham  36.093925
#
#     longitude  ...                                      propertyTaxes  \
# 0  -73.894704  ...          {'2019': {'year': 2019, 'total': 316873}}
# 1  -96.036133  ...            {'2023': {'year': 2023, 'total': 3146}}
# 2 -111.000775  ...  {'2022': {'year': 2022, 'total': 1229}, '2024'...
# 3  -90.474531  ...           {'2022': {'year': 2022, 'total': 11386}}
# 4  -78.967830  ...            {'2020': {'year': 2020, 'total': 2514}}
#
#                                                owner  ownerOccupied  bedrooms  \
# 0  {'names': ['Peiwen Liang'], 'type': 'Individua...            1.0       NaN
# 1  {'names': ['Bert W Thompson'], 'type': 'Indivi...            1.0       2.0
# 2  {'names': ['Rex E Derr', 'Marianne Derr'], 'ty...            0.0       2.0
# 3  {'names': ['LEINART BONITA K TRUST'], 'mailing...            1.0       NaN
# 4  {'names': ['BENJAMIN GRAY ROBINSON'], 'mailing...            1.0       3.0
#
#   bathrooms                          subdivision              lastSaleDate  \
# 0       NaN                                  NaN                       NaN
# 1       1.0                       BENSON GARDENS                       NaN
# 2       2.0  CONTINENTAL VISTAS RESUB TOWNHOUSES  2021-05-10T00:00:00.000Z
# 3       NaN                        HICKORY WOODS  1992-07-01T00:00:00.000Z
# 4       3.0                   HEATHER GLEN SEC 7  2012-11-16T00:00:00.000Z
#
#   lastSalePrice          hoa  \
# 0           NaN          NaN
# 1           NaN          NaN
# 2      209900.0  {'fee': 31}
# 3       50000.0          NaN
# 4      213000.0          NaN
#
#                                              history
# 0                                                NaN
# 1                                                NaN
# 2  {'2021-05-10': {'event': 'Sale', 'date': '2021...
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 29 columns]

# %%
real_estate_df.columns
# Out:
# Index(['id', 'formattedAddress', 'addressLine1', 'addressLine2', 'city',
#        'state', 'zipCode', 'county', 'latitude', 'longitude', 'propertyType',
#        'squareFootage', 'lotSize', 'yearBuilt', 'assessorID',
#        'legalDescription', 'zoning', 'features', 'taxAssessments',
#        'propertyTaxes', 'owner', 'ownerOccupied', 'bedrooms', 'bathrooms',
#        'subdivision', 'lastSaleDate', 'lastSalePrice', 'hoa', 'history'],
#       dtype='object')

# %%
# Transformation Layer
# Replace missing values with appropriate replacements
real_estate_df.fillna({
    'bedrooms': 0.0,
    'bathrooms': 0.0,
    'squareFootage': 0.0,
    'lotSize': 0.0,
    'yearBuilt': 0.0,
    'features': 'Unknown',
    'assessorID': 'Unknown',
    'legalDescription': 'Unknown',
    'ownerOccupied': 0.0,
    'lastSaleDate': 'unknown',
    'propertyType': 'Unknown',
    'propertyTaxes': 'Unknown',
    'subdivision' : 'Unknown',
    'addressLine2': 'Unknown',
    'county': 'Unknown',
    'zoning': 'Unknown',
    'taxAssessments': 'Unknown',
    'hoa': 'Unknown'
      
}, inplace=True)

# %%
real_estate_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 29 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                500 non-null    object
#  1   formattedAddress  500 non-null    object
#  2   addressLine1      500 non-null    object
#  3   addressLine2      102 non-null    object
#  4   city              500 non-null    object
#  5   state             500 non-null    object
#  6   zipCode           500 non-null    int64
#  7   county            499 non-null    object
#  8   latitude          500 non-null    float64
#  9   longitude         500 non-null    float64
#  10  propertyType      407 non-null    object
#  11  squareFootage     388 non-null    float64
#  12  lotSize           367 non-null    float64
#  13  yearBuilt         376 non-null    float64
#  14  assessorID        363 non-null    object
#  15  legalDescription  352 non-null    object
#  16  zoning            188 non-null    object
#  17  features          361 non-null    object
#  18  taxAssessments    358 non-null    object
#  19  propertyTaxes     345 non-null    object
#  20  owner             358 non-null    object
#  21  ownerOccupied     358 non-null    float64
#  22  bedrooms          346 non-null    float64
#  23  bathrooms         378 non-null    float64
#  24  subdivision       310 non-null    object
#  25  lastSaleDate      302 non-null    object
#  26  lastSalePrice     246 non-null    float64
#  27  hoa               8 non-null      object
#  28  history           232 non-null    object
# dtypes: float64(9), int64(1), object(19)
# memory usage: 113.4+ KB

# %%
real_estate_df['features'] = real_estate_df['features'].astype(str)

# %%
real_estate_df['propertyTaxes'] = real_estate_df['propertyTaxes'].astype(str)
real_estate_df['hoa'] = real_estate_df['hoa'].astype(str)

# %%
# creating the dimension tables
location_dim = real_estate_df[['formattedAddress', 'addressLine1', 'addressLine2', 'city', 'state', 'zipCode', 'county', 
                               'latitude', 'longitude']].copy().drop_duplicates().reset_index(drop=True)
location_dim.index.name= 'location_id'

# %%
location_dim = location_dim.reset_index()

# %%
location_dim
# Out:
#      location_id                                  formattedAddress  \
# 0              0  7035 Broadway, Apt C9, Jackson Heights, NY 11372
# 1              1                   2726 N 79th St, Omaha, NE 68134
# 2              2          635 W Redondo Pl, Green Valley, AZ 85614
# 3              3             3300 44th Street Ct, Moline, IL 61265
# 4              4                     8 Ritten Ct, Durham, NC 27712
# ..           ...                                               ...
# 495          495                 609 Park Ln, Fultondale, AL 35068
# 496          496      9100 E Harry St, Apt 3102, Wichita, KS 67207
# 497          497                852 E Larkspur Dr, Sandy, UT 84094
# 498          498             4710 Lafayette Ln W, Estero, FL 33928
# 499          499          4633 Seeley Ave, Downers Grove, IL 60515
#
#             addressLine1 addressLine2             city state  zipCode  \
# 0          7035 Broadway       Apt C9  Jackson Heights    NY    11372
# 1         2726 N 79th St      Unknown            Omaha    NE    68134
# 2       635 W Redondo Pl      Unknown     Green Valley    AZ    85614
# 3    3300 44th Street Ct      Unknown           Moline    IL    61265
# 4            8 Ritten Ct      Unknown           Durham    NC    27712
# ..                   ...          ...              ...   ...      ...
# 495          609 Park Ln      Unknown       Fultondale    AL    35068
# 496      9100 E Harry St     Apt 3102          Wichita    KS    67207
# 497    852 E Larkspur Dr      Unknown            Sandy    UT    84094
# 498  4710 Lafayette Ln W      Unknown           Estero    FL    33928
# 499      4633 Seeley Ave      Unknown    Downers Grove    IL    60515
#
#           county   latitude   longitude
# 0         Queens  40.748368  -73.894704
# 1        Douglas  41.283931  -96.036133
# 2           Pima  31.855366 -111.000775
# 3    Rock Island  41.479891  -90.474531
# 4         Durham  36.093925  -78.967830
# ..           ...        ...         ...
# 495    Jefferson  33.598428  -86.790050
# 496     Sedgwick  37.664658  -97.232050
# 497    Salt Lake  40.562568 -111.867074
# 498          Lee  26.445099  -81.832231
# 499       Dupage  41.802188  -88.020854
#
# [500 rows x 10 columns]

# %%
# sales dimension
sales_dim = real_estate_df[['lastSaleDate', 'lastSalePrice']].copy().drop_duplicates().reset_index(drop=True)
sales_dim.index.name= 'sales_id'

# %%
sales_dim = sales_dim.reset_index()

# %%
sales_dim
# Out:
#      sales_id              lastSaleDate  lastSalePrice
# 0           0                   unknown            NaN
# 1           1  2021-05-10T00:00:00.000Z       209900.0
# 2           2  1992-07-01T00:00:00.000Z        50000.0
# 3           3  2012-11-16T00:00:00.000Z       213000.0
# 4           4  2021-04-26T00:00:00.000Z       370500.0
# ..        ...                       ...            ...
# 298       298  1995-09-01T00:00:00.000Z       244000.0
# 299       299  2020-08-19T00:00:00.000Z       110000.0
# 300       300  2021-07-01T00:00:00.000Z            NaN
# 301       301  2017-07-25T00:00:00.000Z        49500.0
# 302       302  2018-06-12T00:00:00.000Z       517500.0
#
# [303 rows x 3 columns]

# %%
#features_dimension
features_dim = real_estate_df[['bedrooms', 'bathrooms', 'squareFootage', 'features', 
                               'lotSize']].copy().drop_duplicates().reset_index(drop=True)
features_dim.index.name= 'features_id'

# %%
features_dim = features_dim.reset_index()

# %%
features_dim
# Out:
#      features_id  bedrooms  bathrooms  squareFootage  \
# 0              0       0.0        0.0       110000.0
# 1              1       2.0        1.0          896.0
# 2              2       2.0        2.0         1559.0
# 3              3       0.0        0.0         4052.0
# 4              4       3.0        3.0         2398.0
# ..           ...       ...        ...            ...
# 400          400       0.0        0.0         2474.0
# 401          401       3.0        1.0         1210.0
# 402          402       4.0        2.0         1044.0
# 403          403       2.0        2.0          880.0
# 404          404       0.0        3.5         3709.0
#
#                                               features  lotSize
# 0                  {'floorCount': 6, 'unitCount': 135}  23959.0
# 1    {'architectureType': 'Ranch', 'cooling': True,...  16906.0
# 2    {'architectureType': 'Condo / Apartment', 'coo...   3650.0
# 3    {'floorCount': 2, 'garage': True, 'garageType'...      0.0
# 4    {'architectureType': 'Colonial', 'cooling': Tr...  75010.0
# ..                                                 ...      ...
# 400  {'exteriorType': 'Aluminum / Vinyl Siding', 'f...   8276.0
# 401  {'cooling': True, 'coolingType': 'Commercial',...  20000.0
# 402  {'architectureType': 'Ranch', 'cooling': True,...   8276.0
# 403  {'architectureType': 'Mobile Home', 'cooling':...   2265.0
# 404  {'exteriorType': 'Brick', 'floorCount': 2, 'ga...  27443.0
#
# [405 rows x 6 columns]

# %%
property_fact_table = real_estate_df.merge(sales_dim, on=['lastSaleDate', 'lastSalePrice'], how='left')\
                                    .merge(location_dim, on=['formattedAddress', 'addressLine1', 'addressLine2', 'city', 'state', 'zipCode', 'county', 'latitude', 'longitude'], how='left')\
                                    .merge(features_dim, on=['bedrooms', 'bathrooms', 'squareFootage', 'features','lotSize'], how='left')\
                                    [['id', 'location_id', 'sales_id', 'features_id', 'propertyType', 'yearBuilt', 'assessorID', 'legalDescription', 'subdivision', 'zoning', 'hoa', 'propertyTaxes','ownerOccupied']]

# %%
property_fact_table
# Out:
#                                                    id  location_id  sales_id  \
# 0    7035-Broadway,-Apt-C9,-Jackson-Heights,-NY-11372            0         0
# 1                     2726-N-79th-St,-Omaha,-NE-68134            1         0
# 2            635-W-Redondo-Pl,-Green-Valley,-AZ-85614            2         1
# 3               3300-44th-Street-Ct,-Moline,-IL-61265            3         2
# 4                       8-Ritten-Ct,-Durham,-NC-27712            4         3
# ..                                                ...          ...       ...
# 495                 609-Park-Ln,-Fultondale,-AL-35068          495       299
# 496      9100-E-Harry-St,-Apt-3102,-Wichita,-KS-67207          496         0
# 497                852-E-Larkspur-Dr,-Sandy,-UT-84094          497       300
# 498             4710-Lafayette-Ln-W,-Estero,-FL-33928          498       301
# 499          4633-Seeley-Ave,-Downers-Grove,-IL-60515          499       302
#
#      features_id   propertyType  yearBuilt              assessorID  \
# 0              0      Apartment     1927.0            01282-0175C9
# 1              1  Single Family     1952.0              0633290002
# 2              2          Condo     1978.0             304-26-7190
# 3              3  Single Family     1993.0           17-10-221-014
# 4              4  Single Family     1992.0                  184607
# ..           ...            ...        ...                     ...
# 495          401  Single Family     1957.0  13-00-31-3-001-009.000
# 496           12        Unknown        0.0                 Unknown
# 497          402  Single Family     1971.0           28-17-176-005
# 498          403   Manufactured     2018.0  29-46-25-E1-1100E.0060
# 499          404  Single Family     2019.0           09-06-412-010
#
#                                       legalDescription  \
# 0                                     LOT:175 BLK:1282
# 1    BENSON GARDENS LOT 155 BLOCK 0 N 157.5 FT 107 ...
# 2          CONTINENTAL VISTAS RESUB TOWNHOUSES LOT 230
# 3                LOT 4 HICKORY WOODS AND N 10 FT LOT 5
# 4                            HEATHER GLEN/SEC:07/LT#51
# ..                                                 ...
# 495                   LOT 195 FULTONDALE ESTS 2ND SECT
# 496                                            Unknown
# 497   LOT 35 WHITE CITY NO 8 SUB 00000-0000 11096-4760
# 498  RIVERWOODS PLANTATION RV RESORT CONDO PH-IV BL...
# 499                                        EVANS RESUB
#
#                              subdivision   zoning          hoa  \
# 0                                Unknown       R6      Unknown
# 1                         BENSON GARDENS  Unknown      Unknown
# 2    CONTINENTAL VISTAS RESUB TOWNHOUSES  Unknown  {'fee': 31}
# 3                          HICKORY WOODS      MOL      Unknown
# 4                     HEATHER GLEN SEC 7       RR      Unknown
# ..                                   ...      ...          ...
# 495             FULTONDALE EST-2 13-31-3       R2      Unknown
# 496                              Unknown  Unknown      Unknown
# 497                           WHITE CITY     1108      Unknown
# 498                RIVERWOOD PLANTATIONS       RV      Unknown
# 499                          EVANS RESUB        R      Unknown
#
#                                          propertyTaxes  ownerOccupied
# 0            {'2019': {'year': 2019, 'total': 316873}}            1.0
# 1              {'2023': {'year': 2023, 'total': 3146}}            1.0
# 2    {'2022': {'year': 2022, 'total': 1229}, '2024'...            0.0
# 3             {'2022': {'year': 2022, 'total': 11386}}            1.0
# 4              {'2020': {'year': 2020, 'total': 2514}}            1.0
# ..                                                 ...            ...
# 495                                            Unknown            1.0
# 496                                            Unknown            0.0
# 497            {'2023': {'year': 2023, 'total': 2895}}            1.0
# 498            {'2023': {'year': 2023, 'total': 1003}}            1.0
# 499  {'2018': {'year': 2018, 'total': 9390}, '2022'...            1.0
#
# [500 rows x 13 columns]

# %%
property_fact_table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                500 non-null    object
#  1   location_id       500 non-null    int64
#  2   sales_id          500 non-null    int64
#  3   features_id       500 non-null    int64
#  4   propertyType      500 non-null    object
#  5   yearBuilt         500 non-null    float64
#  6   assessorID        500 non-null    object
#  7   legalDescription  500 non-null    object
#  8   subdivision       500 non-null    object
#  9   zoning            500 non-null    object
#  10  hoa               500 non-null    object
#  11  propertyTaxes     500 non-null    object
#  12  ownerOccupied     500 non-null    float64
# dtypes: float64(2), int64(3), object(8)
# memory usage: 50.9+ KB

# %%
property_fact_table.columns
# Out:
# Index(['id', 'location_id', 'sales_id', 'features_id', 'propertyType',
#        'yearBuilt', 'assessorID', 'legalDescription', 'subdivision', 'zoning',
#        'hoa', 'propertyTaxes', 'ownerOccupied'],
#       dtype='object')

# %%
# save into csv
location_dim.to_csv('location_dim.csv', index=False)
sales_dim.to_csv('sales_dim.csv', index=False)
features_dim.to_csv('features_dim.csv', index=False)
property_fact_table.to_csv('property_fact_table_dim.csv', index=False)

# %% [markdown]
# Loading layers

# %%
# Function to get the database connections
def get_db_connection():
    connection = psycopg2.connect(
        host = 'localhost',
        database='zipco_realestate',
        user='postgres',
        password='datapsl2025@'
    )
    return connection

conn = get_db_connection()

# %%
# create functions setting up schemas and tables
def create_tables():
    conn = get_db_connection()
    cursor = conn.cursor()
    create_table_query = '''
                            CREATE SCHEMA IF NOT EXISTS zipco_realestate;

                            DROP TABLE IF EXISTS zipco_realestate.location_dim CASCADE;
                            DROP TABLE IF EXISTS zipco_realestate.sales_dim CASCADE;
                            DROP TABLE IF EXISTS zipco_realestate.features_dim CASCADE;
                            DROP TABLE IF EXISTS zipco_realestate.property_fact_table CASCADE;
                            
                            CREATE TABLE zipco_realestate.location_dim (
                                location_id INTEGER PRIMARY KEY,
                                formattedAddress VARCHAR(1000000),
                                addressLine1 VARCHAR(1000000),
                                addressLine2 VARCHAR(1000000),
                                city VARCHAR(100000),
                                state VARCHAR(100000),
                                zipCode INTEGER,
                                county VARCHAR(100000),
                                latitude FLOAT,
                                longitude FLOAT
                            );
                            
                            CREATE TABLE zipco_realestate.sales_dim (
                                sales_id INTEGER PRIMARY KEY,
                                lastSaleDate VARCHAR(1000000),
                                lastSalePrice FLOAT
                                
                            );
                            
                            CREATE TABLE zipco_realestate.features_dim (
                                features_id INTEGER PRIMARY KEY,
                                bedrooms FLOAT,
                                bathrooms FLOAT,
                                squareFootage FLOAT,
                                features VARCHAR(100000),
                                lotSize FLOAT
                                
                            );
                            
                            CREATE TABLE zipco_realestate.property_fact_table (
                                id VARCHAR(1000000) PRIMARY KEY,
                                location_id INTEGER,
                                sales_id INTEGER,
                                features_id INTEGER,
                                propertyType VARCHAR(100000),
                                yearBuilt FLOAT,
                                assessorID VARCHAR(100000),
                                legalDescription VARCHAR(100000),
                                subdivision VARCHAR(100000),
                                zoning VARCHAR(100000),
                                hoa VARCHAR(1000000),
                                propertyTaxes VARCHAR(1000000),
                                ownerOccupied FLOAT,
                                FOREIGN KEY(location_id) REFERENCES zipco_realestate.location_dim(location_id),
                                FOREIGN KEY(sales_id) REFERENCES zipco_realestate.sales_dim(sales_id),
                                FOREIGN KEY(features_id) REFERENCES zipco_realestate.features_dim(features_id)
                            );
    
                            '''
    cursor.execute(create_table_query)
    conn.commit()
    cursor.close()
    conn.close()

# %%
create_tables()

# %%
## loading the data into the database tables
conn = get_db_connection()
cursor = conn.cursor()
    
# Insert dataframe into the SQL tables
for _,row in location_dim.iterrows():
    cursor.execute(
    '''INSERT INTO zipco_realestate.location_dim (location_id, formattedAddress, addressLine1, addressLine2,
            city, state, zipCode, county, latitude, longitude)
          VALUES(%s, %s, %s, %s, %s, %s, %s, %s, %s, %s)''',
        (row['location_id'], row['formattedAddress'], row['addressLine1'], row['addressLine2'], row['city'], \
            row['state'], row['zipCode'], row['county'], row['latitude'], row['longitude'])
            
    )
    
for _,row in sales_dim.iterrows():
    cursor.execute(
    '''INSERT INTO zipco_realestate.sales_dim (sales_id, lastSaleDate, lastSalePrice)
          VALUES(%s, %s, %s)''',
        (row['sales_id'], row['lastSaleDate'], row['lastSalePrice'])
    
    )
    
    
    
for _,row in features_dim.iterrows():
    cursor.execute(
    '''INSERT INTO zipco_realestate.features_dim (features_id, bedrooms, bathrooms, squareFootage, features,
            lotSize)
          VALUES(%s, %s, %s, %s, %s, %s)''',
        (row['features_id'], row['bedrooms'], row['bathrooms'], row['squareFootage'], row['features'], \
              row['lotSize'])
    
    )
    
for _,row in property_fact_table.iterrows():
    cursor.execute(
    '''INSERT INTO zipco_realestate.property_fact_table(id, location_id, sales_id, features_id, propertyType,
            yearBuilt, assessorID, legalDescription, subdivision, zoning, 
            hoa, propertyTaxes, ownerOccupied)
          VALUES(%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)''',
        (row['id'], row['location_id'], row['sales_id'], row['features_id'], row['propertyType'], \
            row['yearBuilt'], row['assessorID'], row['legalDescription'], row['subdivision'], row['zoning'], \
             row['hoa'], row['propertyTaxes'], row['ownerOccupied'])
    
    )
    
# commit changes
conn.commit()

#close connection
cursor.close()
conn.close()

# %%
display(property_fact_table.head())
